# %% [markdown]
# # Hello
#
# The tracked sample notebook. It exists so the notebook machinery stays under test:
# the topic notebooks (`SNN-slug.ipynb`) are **local-only and gitignored**, so on a
# fresh clone or in CI there is nothing else for the runner to run.
#
# It uses the standard library only, on purpose. A sample that imported an exercise
# package would go red whenever that exercise changed, and it would be testing the
# exercise rather than the thing it is here to test — that a notebook in this repo can
# be opened, executed top to bottom, and finish without raising.

# %%
import platform
import sys

print('hello from', platform.python_implementation(), platform.python_version())
assert sys.version_info >= (3, 12), 'this repo targets Python 3.12'

# %% [markdown]
# A second cell, so the runner is proven to advance past the first.

# %%
print('the notebook harness works')
